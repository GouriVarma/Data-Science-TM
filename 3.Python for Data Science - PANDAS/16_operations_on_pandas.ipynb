# %% [markdown]
# ##exploring dataframes

# %%
import pandas as pd

# %%
#iris dataset
iris=pd.read_csv('Iris.csv')

# %%
iris.head()     #species of a flower
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#select a column
iris['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
iris.SepalLengthCm
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
iris['SepalLengthCm'].max()
# Out:
# 7.9

# %%
iris['SepalLengthCm'].min()
# Out:
# 4.3

# %%
iris[['SepalLengthCm','PetalLengthCm']].min()
# Out:
# SepalLengthCm    4.3
# PetalLengthCm    1.0
# dtype: float64

# %%
#add a new column
iris['new_column']=iris['PetalLengthCm']+iris['SepalLengthCm']

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    new_column
# 0         6.5
# 1         6.3
# 2         6.0
# 3         6.1
# 4         6.4

# %%
#drop the columns
iris=iris.drop('new_column',axis=1)

# %%
#drop rows
iris.drop([0],inplace=True)

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris['Species'].nunique()
# Out:
# 3

# %%
iris['SepalLengthCm'].count()
# Out:
# 149

# %%
iris['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: Species, dtype: int64

# %%
#filtering

# %%
iris[iris['Species']=='Iris-setosa']
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
iris[(iris['Species']=='Iris-setosa')&(iris['PetalLengthCm']>1.6)]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa

# %%
#filtering using lists
length=[3.3,3,3.4]
iris[iris['SepalWidthCm'].isin(length)]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      2            4.9           3.0            1.4           0.2
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 20    21            5.4           3.4            1.7           0.2
# 23    24            5.1           3.3            1.7           0.5
# 24    25            4.8           3.4            1.9           0.2
# 25    26            5.0           3.0            1.6           0.2
# 26    27            5.0           3.4            1.6           0.4
# 28    29            5.2           3.4            1.4           0.2
# 31    32            5.4           3.4            1.5           0.4
# ...
