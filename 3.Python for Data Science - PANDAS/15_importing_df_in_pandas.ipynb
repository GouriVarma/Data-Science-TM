# %%
import pandas as pd

# %%
df=pd.read_csv('/content/cereal.csv')

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.head(16)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                 Apple Jacks   K    C       110        2    0     125    1.0
# 7                     Basic 4   G    C       130        3    2     210    2.0
# 8                   Bran Chex   R    C        90        2    1     200    4.0
# 9                 Bran Flakes   P    C        90        3    0     210    5.0
# 10               Cap'n'Crunch   Q    C       120        1    2     220    0.0
# ...

# %%
df.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %%
df.tail(15)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 62              Rice Krispies   K    C       110        2    0     290    0.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 66                     Smacks   K    C       110        2    1      70    1.0
# 67                  Special K   K    C       110        6    0     230    1.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
# 69          Total Corn Flakes   G    C       110        2    1     200    0.0
# 70          Total Raisin Bran   G    C       140        3    1     190    4.0
# 71          Total Whole Grain   G    C       100        3    1     200    3.0
# 72                    Triples   G    C       110        2    1     250    0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
df.shape
# Out:
# (77, 16)

# %%
df.size
# Out:
# 1232

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
#selecting columns
df['calories']
# Out:
# 0      70
# 1     120
# 2      70
# 3      50
# 4     110
#      ...
# 72    110
# 73    110
# 74    100
# 75    100
# 76    110
# Name: calories, Length: 77, dtype: int64

# %%
df[['calories','vitamins']]
# Out:
#     calories  vitamins
# 0         70        25
# 1        120         0
# 2         70        25
# 3         50        25
# 4        110        25
# ..       ...       ...
# 72       110        25
# 73       110        25
# 74       100        25
# 75       100        25
# 76       110        25
#
# [77 rows x 2 columns]

# %%
#indexing
df.loc[2]
# Out:
# name         All-Bran
# mfr                 K
# type                C
# calories           70
# protein             4
# fat                 1
# sodium            260
# fiber             9.0
# carbo             7.0
# sugars              5
# potass            320
# vitamins           25
# shelf               3
# weight            1.0
# cups             0.33
# rating      59.425505
# Name: 2, dtype: object

# %%
df.iloc[0]
# Out:
# name        100% Bran
# mfr                 N
# type                C
# calories           70
# protein             4
# fat                 1
# sodium            130
# fiber            10.0
# carbo             5.0
# sugars              6
# potass            280
# vitamins           25
# shelf               3
# weight            1.0
# cups             0.33
# rating      68.402973
# Name: 0, dtype: object

# %%
df=pd.read_csv('cereal.csv',index_col='type')

# %%
df.head()
# Out:
#                            name mfr  calories  protein  fat  sodium  fiber  \
# type
# C                     100% Bran   N        70        4    1     130   10.0
# C             100% Natural Bran   Q       120        3    5      15    2.0
# C                      All-Bran   K        70        4    1     260    9.0
# C     All-Bran with Extra Fiber   K        50        4    0     140   14.0
# C                Almond Delight   R       110        2    2     200    1.0
#
#       carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# type
# C       5.0       6     280        25      3     1.0  0.33  68.402973
# C       8.0       8     135         0      3     1.0  1.00  33.983679
# C       7.0       5     320        25      3     1.0  0.33  59.425505
# C       8.0       0     330        25      3     1.0  0.50  93.704912
# C      14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.loc['C']
# Out:
#                            name mfr  calories  protein  fat  sodium  fiber  \
# type
# C                     100% Bran   N        70        4    1     130   10.0
# C             100% Natural Bran   Q       120        3    5      15    2.0
# C                      All-Bran   K        70        4    1     260    9.0
# C     All-Bran with Extra Fiber   K        50        4    0     140   14.0
# C                Almond Delight   R       110        2    2     200    1.0
# ...                         ...  ..       ...      ...  ...     ...    ...
# C                       Triples   G       110        2    1     250    0.0
# C                          Trix   G       110        1    1     140    0.0
# C                    Wheat Chex   R       100        3    1     230    3.0
# C                      Wheaties   G       100        3    1     200    3.0
# C           Wheaties Honey Gold   G       110        2    1     200    1.0
#
# ...

# %%
df.iloc['C']   #non-integer key
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-70729b2597f8> in <module>
# ----> 1 df.iloc['C']
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1518             key = item_from_zerodim(key)
#    1519             if not is_integer(key):
# -> 1520                 raise TypeError("Cannot index by location index with a non-integer key")
#    1521
#    1522             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
#slice

# %%
df=pd.read_csv('cereal.csv')

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.loc[1:45]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 8                                Bran Chex   R    C        90        2    1
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 11                                Cheerios   G    C       110        6    2
# ...
